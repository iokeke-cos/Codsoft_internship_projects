# %%
#Project to make rock,paper,scissors game using tkinter
import tkinter as tk
from tkinter import *
from random import randint
from tkinter import ttk

#creation of window
root = tk.Tk()
root.title ("Rock ,Paper, Scissors Game") 
root.config(bg = "white")
root.geometry("500x600")


#Defining images
rock = PhotoImage(file = 'C:/Users/User/Desktop/Coding stuff/Codsoft_internship_projects/images/image1.png')
paper =PhotoImage(file = 'C:/Users/User/Desktop/Coding stuff/Codsoft_internship_projects/images/image2.png')
scissors =PhotoImage(file = 'C:/Users/User/Desktop/Coding stuff/Codsoft_internship_projects/images/image3.png')

#Add images to list
image_list = [rock,paper,scissors]

#pick random number between 0 and 2
pick_number = randint(0,2)

#put image on screen
image_label = Label (root,image = image_list[pick_number])
image_label.pack()


#creatin button event
def play():
    #selecting random number
    pick_number = randint(0,2)
    #showing images
    image_label.config(image = image_list[pick_number])
    # reminder: 0= Rock ,1= Paper ,2 = Scissors
    
    #converting choice pick to integer
    if choice.get() =="Rock":
        userchoice_value = 0
    elif choice.get() == "Paper":
        userchoice_value = 1
    elif choice.get() == "Scissoors":
        userchoice_value = 2
    #Determine winner outcome
    if userchoice_value == 0: #Rock
        if pick_number == 0:
            outcome_label.config(text = "IT'S A DRAW! PLAY AGAIN...")
        elif pick_number == 1:
            outcome_label.config(text = "PAPER COVERS ROCK...YOU LOSE")
        elif pick_number == 2:
            outcome_label.config(text = "ROCK BEATS SCISSORS...YOU WIN!!!")

    if userchoice_value == 1: #Paper
        if pick_number == 0:
            outcome_label.config(text = "PAPER COVERS ROCK...YOU WIN!!!")
        elif pick_number == 1:
            outcome_label.config(text = "IT'S A DRAW! PLAY AGAIN...")
        elif pick_number == 2:
            outcome_label.config(text = "SCISSORS CUTS PAPER...YOU LOSE")

    if userchoice_value == 2: #Scissors
        if pick_number == 0:
            outcome_label.config(text = "ROCK BEATS SCISSORS...YOU LOSE")
        elif pick_number == 1:
            outcome_label.config(text = "SCISSORS CUTS PAPER...YOU WIN!!!")
        elif pick_number == 2:
            outcome_label.config(text = "IT'S A DRAW! PLAY AGAIN...")


            


# choice pick
choice = ttk.Combobox(root,value = ("Rock","Paper","Scissors"))
choice.current(0)
choice.pack(pady = 20)
    
#creating button
play_button = Button(root,text = "PLAY!",command = play)
play_button.pack(pady = 10)

#label for winner outcome
outcome_label = Label(root, text = "",font = ("Helvetica",12))
outcome_label.pack(pady = 40)





root.mainloop()
